# %% [markdown]
# #  Análise de Gastos e Comportamento de Clientes
#
# Projeto focado em entender padrões de consumo e gerar insights para tomada de decisão em contexto de fintech.

# %%
# !pip install plotly

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

n = 200

clientes = [f'Cliente_{i}' for i in range(1, 21)]
categorias = ['Alimentação', 'Transporte', 'Lazer', 'Saúde', 'Compras']

data = pd.DataFrame({
    'cliente': np.random.choice(clientes, n),
    'categoria': np.random.choice(categorias, n),
    'valor': np.random.uniform(20, 500, n).round(2),
    'data': pd.date_range(start='2024-01-01', periods=n)
})

# %%
perfil = data.groupby('cliente').agg({
    'valor': ['sum', 'mean', 'count']
})

perfil.columns = ['total_gasto', 'media_gasto', 'qtd_transacoes']

perfil = perfil.sort_values('total_gasto', ascending=False)

# %%
perfil['segmento'] = pd.cut(
    perfil['total_gasto'],
    bins=[0, 2000, 4000, 10000],
    labels=['Baixo', 'Médio', 'Alto']
)

# %%
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        "Top Clientes",
        "Gastos por Categoria",
        "Evolução de Gastos",
        "Segmentação"
    ),
    specs=[[{"type": "bar"}, {"type": "domain"}],
           [{"type": "scatter"}, {"type": "bar"}]]
)

# Top clientes
fig.add_trace(
    go.Bar(
        x=top_clientes['cliente'],
        y=top_clientes['total_gasto'],
        marker_color='#8A05BE'
    ),
    row=1, col=1
)

# Categorias (donut)
fig.add_trace(
    go.Pie(
        labels=gasto_categoria['categoria'],
        values=gasto_categoria['valor'],
        hole=0.6
    ),
    row=1, col=2
)

# Evolução
fig.add_trace(
    go.Scatter(
        x=gasto_tempo['data'],
        y=gasto_tempo['valor'],
        mode='lines',
        line=dict(color='#8A05BE')
    ),
    row=2, col=1
)

# Segmentação
fig.add_trace(
    go.Bar(
        x=segmento['segmento'],
        y=segmento['quantidade'],
        marker_color='#8A05BE'
    ),
    row=2, col=2
)

fig.update_layout(
    height=700,
    template='plotly_dark',
    paper_bgcolor='#0f172a',
    plot_bgcolor='#0f172a',
    font=dict(color='white'),
    title="Dashboard de Clientes - Análise Fintech"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
